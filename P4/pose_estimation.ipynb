# %% [markdown]
# # ROB 498-004/599-004 Project 4-1: Pose Estimation - PoseCNN
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Anthony OPIPARI, #12345678

# %% [markdown]
# **Your Answer:**
# Firstname Lastname, #UMID

# %% [markdown]
# # PoseCNN: A Classic end-to-end pose estimation network
#
# In this exercise you will implement an **end-to-end** object pose estimator, based on [PoseCNN](https://arxiv.org/abs/1711.00199), which consists of two stages - feature extraction with a backbone network and pose estimation represented by instance segmentation, 3D translation estimation, and 3D rotation estimation.
# We will train it to estimate the pose of a set of object classes and evaluate the estimation accuracy.

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as previous assignments. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
running_colab = 'google.colab' in str(get_ipython())

if running_colab:
    from google.colab import drive
    print('Running on Colab')
    drive.mount('/content/drive/', force_remount=True)
else:
    print('Running locally')
# Out:
# Running locally

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the following cell should print the filenames from the assignment:
#
# ```
# ["pose_estimation.ipynb", "vision_transformers.ipynb", "rob599", "pose_estimation.py", "vision_transformers.py"]
# ```

# %%
import os
import sys

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2025WN folder and put all the files under P4 folder, then "2025WN/P4"
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2025WN/P4'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = None
GOOGLE_DRIVE_PATH = './'#os.path.join("drive", "My Drive", GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))


# Add to sys so we can import .py files.
sys.path.append(GOOGLE_DRIVE_PATH)
# Out:
# ['PROPS-Pose-Dataset.tar.gz', '__pycache__', 'vision_transformers.ipynb', 'posecnn_model.pth', 'pose_cnn.py', 'rob599', 'vision_transformers.py', 'pose_estimation.ipynb', 'PROPS-Pose-Dataset']

# %% [markdown]
# Next, we install a couple packages to help with processing and visualizing object models.

# %%
import os
# os.environ['PYOPENGL_PLATFORM'] = 'egl'

# %pip install tqdm
# %pip install trimesh
# %pip install pyrender
# %pip install pyquaternion
# Out:
# Requirement already satisfied: tqdm in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trimesh in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (4.6.5)
# Requirement already satisfied: numpy>=1.20 in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from trimesh) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyrender in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (0.1.45)
# Requirement already satisfied: freetype-py in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (2.5.1)
# Requirement already satisfied: imageio in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (2.37.0)
# Requirement already satisfied: networkx in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (3.4.2)
# Requirement already satisfied: numpy in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (1.26.4)
# Requirement already satisfied: Pillow in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (11.1.0)
# Requirement already satisfied: pyglet>=1.4.10 in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (2.1.3)
# Requirement already satisfied: PyOpenGL==3.1.0 in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (3.1.0)
# Requirement already satisfied: scipy in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (1.15.2)
# Requirement already satisfied: six in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (1.16.0)
# Requirement already satisfied: trimesh in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyrender) (4.6.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyquaternion in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (0.9.9)
# Requirement already satisfied: numpy in /home/mirrorlab/anaconda3/envs/deeprob_new/lib/python3.10/site-packages (from pyquaternion) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run the following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from pose_cnn.py!
# Hello from p4_helpers.py!
# ```
#
# as well as the last edit time for the file `pose_cnn.py`.

# %%
import os
import time

os.environ["TZ"] = "US/Eastern"
time.tzset()

from pose_cnn import hello_pose_cnn
from rob599.p4_helpers import hello_helper


hello_pose_cnn()
hello_helper()

pose_cnn_path = os.path.join(GOOGLE_DRIVE_PATH, "pose_cnn.py")
pose_cnn_edit_time = time.ctime(
    os.path.getmtime(pose_cnn_path)
)
print("pose_cnn.py last edited on %s" % pose_cnn_edit_time)
# Out:
# Hello from pose_cnn.py!
# Hello from p4_helpers.py!
# pose_cnn.py last edited on Sat Mar 29 19:53:24 2025

# %% [markdown]
# Load several useful packages that are used in this notebook:

# %%
import os
import time

import matplotlib.pyplot as plt
import torch
import torchvision

# %matplotlib inline

from rob599.p4_helpers import *
from rob599 import reset_seed
from rob599.grad import rel_error

# for plotting
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots
plt.rcParams["font.size"] = 16
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %% [markdown]
# We will use GPUs to accelerate our computation in this notebook. Run the following to make sure GPUs are enabled:

# %%
if torch.cuda.is_available():
    print("Good to go!")
    DEVICE = torch.device("cuda")
else:
    print("Please set GPU via Edit -> Notebook Settings.")
    DEVICE = torch.device("cpu")
# Out:
# Good to go!

# %% [markdown]
# ## Load PROPS Pose Dataset
# During the majority of our homework assignments so far, we have used the PROPS Classification or Detection datasets for image processing tasks.
#
# In order to train and evaluate object pose estimation models, we need a dataset where each image is annotated with a *set* of *pose labels*, where each pose label gives the 3DoF position and 3DoF orientation of some object in the image.
#
# We will use the [PROPS Pose](https://deeprob.org/datasets/props-pose/) dataset, which provides annotations of this form.
# Our PROPS Detection dataset is much smaller than typical benchmarking pose estimation datasets, and thus easier to manage in an homework assignment.
# PROPS comprises annotated bounding boxes for 10 object classes:
# `["master_chef_can", "cracker_box", "sugar_box", "tomato_soup_can", "mustard_bottle", "tuna_fish_can", "gelatin_box", "potted_meat_can", "mug", "large_marker"]`.
# The choice of these objects is inspired by the [YCB object and Model set](https://ieeexplore.ieee.org/document/7251504) commonly used in robotic perception models.
#
# We create a [`PyTorch Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) class
# named `PROPSPoseDataset` in `rob599/PROPSPoseDataset.py` that will download the PROPS Pose dataset.
#
# Run the following two cells to set a few config parameters and then download the train/val sets for the PROPS Pose dataset.

# %%
import multiprocessing

# Set a few constants related to data loading.
NUM_CLASSES = 10
BATCH_SIZE = 4
NUM_WORKERS = multiprocessing.cpu_count()

# %%
from rob599 import PROPSPoseDataset
 
# NOTE: Set `download=True` for the first time when you set up Google Drive folder.
# Turn it back to `False` later for faster execution in the future.
# If this hangs, download and place data in your drive manually.
train_dataset = PROPSPoseDataset(
    GOOGLE_DRIVE_PATH, "train",
    download=False  # True (for the first time)
) 
val_dataset = PROPSPoseDataset(GOOGLE_DRIVE_PATH, "val")

print(f"Dataset sizes: train ({len(train_dataset)}), val ({len(val_dataset)})")
# Out:
# Dataset sizes: train (500), val (500)

# %% [markdown]
# This dataset will format each sample from the dataset as a dictionary containing the following keys:
#
#  - 'rgb': a numpy float32 array of shape (3, 480, 640) scaled to range [0,1]
#  - 'depth': a numpy int32 array of shape (1, 480, 640) in (mm)
#  - 'objs_id': a numpy uint8 array of shape (10,) containing integer ids for visible objects (1-10) and invisible objects (0)
#  - 'label': a numpy bool array of shape (11, 480, 640) containing instance segmentation for objects in the scene
#  - 'bbx': a numpy float64 array of shape (10, 4) containing (x, y, w, h) coordinates of object bounding boxes
#  - 'RTs': a numpy float64 array of shape (10, 3, 4) containing homogeneous transformation matrices per object into camera coordinate frame
#  - 'centermaps': a numpy float64 array of shape (30, 480, 640) containing (dx, dy, z) coordinates to each object's centroid
#  - 'centers': a numpy float64 array of shape (10, 2) containing (x, y) coordinates of object centroids projected to image plane
#
# This dataset assumes that the upper left of the image is the origin point (0, 0).

# %% [markdown]
# ### Visualize Dataset
#
# Now let's visualize a few samples from our validation set to make sure the images and labels are loaded correctly. In this next cell, we'll use the `visualize_dataset` function from `rob599/utils.py` to view the RGB observation and labeled pose labels for three random samples.
#
# In the below figure, the final column plots the centermaps for class 0, which corresponds to the master chef coffee can. This plot is included to give a sense of how the centermaps represent gradients towards the object's centroid.

# %%
from rob599 import reset_seed, visualize_dataset

reset_seed(0)

grid_vis = visualize_dataset(val_dataset,alpha = 0.25)
plt.axis('off')
plt.imshow(grid_vis)
plt.show()

# %% [markdown]
# ## Implementing PoseCNN
#
# Now that we have our dataset loaded and ready to use, we'll begin implementing a variant of the [PoseCNN](https://arxiv.org/abs/1711.00199) network. This architecture is designed to take an RGB color image as input and produce a [6 degrees-of-freedom pose](https://en.wikipedia.org/wiki/Six_degrees_of_freedom) estimate for each instance of an object within the scene from which the image was taken. To do this, PoseCNN uses 5 operations within the architecture. First, a backbone convolutional feature extraction network is used to produce a tensor representing learned features from the input image. Second, the extracted features are processed by an embedding branch to reduce the spatial resolution and memory overhead for downstream layers. Third, an instance segmentation branch uses the embedded features to identify regions in the image corresponding to each object instance (regions of interest). Fourth, the translations for each object instance are estimated using a translation branch along with the embedded features. Finally, a rotation branch uses the embedded features to estimate a rotation, in the form of a [quaternion](https://en.wikipedia.org/wiki/Quaternions_and_spatial_rotation), for each region of interest.
#
# Thr architecture is shown in more detail from Figure 2 of the [PoseCNN paper](https://arxiv.org/abs/1711.00199):
#
# ![architecture](https://deeprob.org/w24/assets/images/posecnn_arch.png)
#
# Now, we will implement a variant of this architecture that performs each of the 5 operations using PyTorch and data from our `PROPSPoseDataset`. The remainder of the features for this project will be implemented in the `pose_cnn.py` file.

# %% [markdown]
# ## Implementing the Backbone and Feature Extraction Branch
#
# In the past project, you implemented a deep convolutional network from scratch. In this project, we'll use [torchvision's](https://pytorch.org/vision/stable/index.html) pretrained convolutional networks for our backbone convolutional feature extractor. Specifically, we'll use the [VGG16 model](https://arxiv.org/abs/1409.1556) as our feature extractor:

# %%
import torchvision.models as models

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

# %% [markdown]
# We can inspect the definition of this model by referring to the [model's source code within torchvision](https://pytorch.org/vision/main/_modules/torchvision/models/vgg.html). From this definition, we can see that the `vgg16.features` variable stores the feature extraction portion of VGG16 before average pooling. We'll use this pretrained VGG16 model for our PoseCNN model's pretrained extraction backbone. Print out the layers in `vgg16.features` by running the code cell below:

# %%
vgg16.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# Using this `vgg16` model as the `pretrained_network`, we implement PoseCNN's feature extraction branch for you in the `FeatureExtraction` class of `pose_cnn.py`. You should inspect this function to understand how the output `feature1` and `feature2` tensors are created. In addition, observe that we freeze the early layers of our pretrained network by setting the corresponding convolutional weights and bias to have `requires_grad=False`. Freezing these layers will speed up training and help reduce overfitting.
#
# We can inspect the expected sizes of `feature1` and `feature2` by passing the `FeatureExtraction` dummy input:

# %%
import torchvision.models as models
from pose_cnn import FeatureExtraction

# Based on PoseCNN section III.B, the output features should 
# be 1/8 and 1/16 the input's spatial resolution with 512 channels
print('feature1 expected shape: (N, {}, {}, {})'.format(512, 480//8, 640//8))
print('feature2 expected shape: (N, {}, {}, {})'.format(512, 480//16, 640//16))
print()

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
feature1, feature2 = feature_extractor(dummy_input)

print('feature1 shape:', feature1.shape)
print('feature2 shape:', feature2.shape)
# Out:
# feature1 expected shape: (N, 512, 60, 80)
# feature2 expected shape: (N, 512, 30, 40)
#
# feature1 shape: torch.Size([2, 512, 60, 80])
# feature2 shape: torch.Size([2, 512, 30, 40])

# %% [markdown]
# Before moving on to the embedding and segmentation branch, take a moment to connect our `feature1` and `feature2` variables with the PoseCNN figure 2 shown earlier in the notebook. Understanding which arrows corresponds to `feature1` and `feature2` will make the remaining networks more comprehensible.

# %% [markdown]
# ## Implementing Segmentation Branch
#
# Now that we have our feature extractor setup, we'll implement the instnace segmentation branch. This branch should fuse information from the feature extractor (`feature1` and `feature2`) according to the architecture diagram of PoseCNN. Specifically, the network will pass both outputs from the feature extractor through a 1x1 convolution+ReLU layer followed by interpolation and an element wise addition. Next these intermediate features are interpolated back to the input image size followed by a final 1x1 convolution+ReLU layer to predict a probability for each class or background at each pixel. Follow the instructions in the `SegmentationBranch` class of `pose_cnn.py` to implement this branch.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, SegmentationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)
segmentation_branch = SegmentationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
feature1, feature2 = feature_extractor(dummy_input)
probability, segmentation, bbx = segmentation_branch(feature1, feature2)

print('probability expected shape: (B, 11, 480, 640)')
print('segmentation expected shape: (B, 480, 640)')
print('bbx expected shape: (N, 6) (where N is the number of rois extracted from the predicted segmentation)')
print()
print('probability shape:', probability.shape)
print('segmentation shape:', segmentation.shape)
print('bbx shape:', bbx.shape)
# Out:
# probability expected shape: (B, 11, 480, 640)
# segmentation expected shape: (B, 480, 640)
# bbx expected shape: (N, 6) (where N is the number of rois extracted from the predicted segmentation)
#
# probability shape: torch.Size([2, 11, 480, 640])
# segmentation shape: torch.Size([2, 480, 640])
# bbx shape: torch.Size([6, 6])

# %% [markdown]
# ### Adding Instance Segmentation Branch to PoseCNN
#
# Now that we have our instance segmentation branch implemented, we can begin building up our `PoseCNN` class. In `pose_cnn.py` use the given `FeatureExtraction` class and your implemented `SegmentationBranch` to initialize the extraction and segmentation portion of PoseCNN. Next, implement the training and testing time forward pass of `PoseCNN` to perform only instance segmentation. We will come back and add rotation+translation branches once we are confident in our instance segmentation.

# %% [markdown]
# ### Training PoseCNN to Perform Instance Segmentation
#
# Once you've added code to initialize and perform the forward pass of PoseCNN for feature extraction and instance segmentation, we can attempt to train this part of PoseCNN by itself. The code in the following cell will initialize a PoseCNN model and begin training it on instance segmentation only. You should expect to see your training loss decrease to ~0.1 after training for 2 epochs.

# %%
import time
from torch.utils.data import DataLoader
import torchvision.models as models

from rob599 import reset_seed
from pose_cnn import PoseCNN
from tqdm import tqdm

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1).to(DEVICE)
posecnn_model = PoseCNN(pretrained_backbone = vgg16,
                       models_pcd = torch.tensor(train_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                       cam_intrinsic = train_dataset.cam_intrinsic).to(DEVICE)

dataloader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE)
optimizer = torch.optim.Adam(posecnn_model.parameters(), lr=0.001,
                                 betas=(0.9, 0.999))

posecnn_model.train()

loss_history = []
log_period = 5
_iter = 0

st_time = time.time()
for epoch in range(3):
    train_loss = []
    for batch in tqdm(dataloader):
        for item in batch:
            batch[item] = batch[item].to(DEVICE)
        loss_dict = posecnn_model(batch)
        optimizer.zero_grad()
        total_loss = loss_dict["loss_segmentation"]
        total_loss.backward()
        optimizer.step()
        train_loss.append(total_loss.item())
    
        if _iter % log_period == 0:
            loss_history.append(total_loss.item())
        _iter += 1
    
    print('Time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + \
                                  ', ' + 'Epoch %02d' % epoch + ', ' + 'Training finished' + f' , with mean training loss {np.array(train_loss).mean()}'))
    
plt.title("Training loss history")
plt.xlabel(f"Iteration (x {log_period})")
plt.ylabel("Loss")
plt.plot(loss_history)
plt.show()

# %% [markdown]
# ### Inference for Instance Segmentation
#
# Now that we have our segmentation network trained, we can qualitatively evaluate the segmentation results. The following notebook cell will visualize output segmentations on a sample from the validation set.

# %%
from torchvision.utils import make_grid

reset_seed(0)

num_samples = 3
posecnn_model.eval()

plt.text(300, -40, 'RGB', ha="center")
plt.text(950, -40, 'True\nSegmentation', ha="center")
plt.text(1600, -40, 'Predicted\nSegmentation', ha="center")

samples = []
for sample_i in range(num_samples):
    sample_idx = random.randint(0,len(val_dataset)-1)
    sample = val_dataset[sample_idx]
    
    rgb = torch.tensor(sample['rgb'][None, :]).to(DEVICE)
    _, prediction = posecnn_model({'rgb': rgb})
    prediction = prediction.cpu().numpy().astype(np.float64)
    prediction /= prediction.max()
    prediction = (np.tile(prediction, (3, 1, 1)) * 255).astype(np.uint8)
    rgb = (sample['rgb'].transpose(1, 2, 0) * 255).astype(np.uint8)
    depth = ((np.tile(sample['depth'], (3, 1, 1)) / sample['depth'].max()) * 255).astype(np.uint8)
    segmentation = (sample['label']*np.arange(11).reshape((11,1,1))).sum(0,keepdims=True).astype(np.float64)
    segmentation /= segmentation.max()
    segmentation = (np.tile(segmentation, (3, 1, 1)) * 255).astype(np.uint8)
    
    samples.append(torch.tensor(rgb.transpose(2, 0, 1)))
    samples.append(torch.tensor(segmentation))
    samples.append(torch.tensor(prediction))

img = make_grid(samples, nrow=3).permute(1, 2, 0)

plt.axis('off')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 reset_seed(0)
#       5 num_samples = 3
# ----> 6 posecnn_model.eval()
#       8 plt.text(300, -40, 'RGB', ha="center")
#       9 plt.text(950, -40, 'True\nSegmentation', ha="center")
#
# NameError: name 'posecnn_model' is not defined

# %% [markdown]
# Before moving on, visually inspect the segmentation results above to ensure your forward functions and loss calculations are setup correctly.

# %% [markdown]
# ## Implementing the Translation Branch
#
# Now that we have our feature extractor and instance segmentation working, we'll implement the rotation and translation branches of PoseCNN. We suggest starting with the translation branch, which follows a similar embedding structure as was used for instance segmentation. Based on the architecture described in the paper, implement your translation network in the `TranslationBranch` class of `pose_cnn.py`.
#
# Once you have implemented `TranslationBranch`, the following notebook cell can be used to verify the shape of your output.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, TranslationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)
translation_branch = TranslationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
feature1, feature2 = feature_extractor(dummy_input)
translation = translation_branch(feature1, feature2)

print('translation expected shape: (2, 30, 480, 640)')
print()
print('translation shape:', translation.shape)
# Out:
# translation expected shape: (2, 30, 480, 640)
#
# translation shape: torch.Size([2, 30, 480, 640])

# %% [markdown]
# ## Implementing the Rotation Branch
#
# Now you can implement the final module of PoseCNN: the rotation branch. This portion of PoseCNN will be reminiscient of fasterRCNN in that we will predict a quaternion for each possible class at each region of interest detected by our preceeding segmentation branch. To do this, we'll need to use ROIPooling for feature extraction. Since you implemented ROIPooling in the last project, feel free to use the [ROIPool](https://pytorch.org/vision/main/generated/torchvision.ops.RoIPool.html) implemented by `torchvision.ops` for this project.
#
# Once you have implemented `RotationBranch`, the following notebook cell can be used to verify the shape of your output.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, RotationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)
rotation_branch = RotationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
dummy_bbx = torch.zeros((10,5)) # N = 10
feature1, feature2 = feature_extractor(dummy_input)
quaternion = rotation_branch(feature1, feature2, dummy_bbx)

print('quaternion expected shape: (N, 40)')
print()
print('quaternion shape:', quaternion.shape)
# Out:
# quaternion expected shape: (N, 40)
#
# quaternion shape: torch.Size([10, 40])

# %% [markdown]
# ## Hough Voting Layer
#
# One important piece of the PoseCNN architecture for inference time that we haven't implemented yet is a Hough voting layer. As described in the text, and illustrated below, a Hough voting layer is used during inference time to extract a single centroid prediction from the translation maps produced by `TranslationBranch` and the segments produced by `SegmentationBranch`. Due to the timing constraints of our semester, we have implemented this Hough voting layer for you in `rob599/p4_helpers.py` as the `HoughVoting` function. We recommend you use our provided `HoughVoting` function after reading through its implementation to understand how it works
#
# ![hough](https://deeprob.org/w24/assets/images/posecnn_hough.png)
#
# We also recommend reading through other given helper functions in `rob599/p4_helpers.py` and the class definition of `PoseCNN` in `pose_cnn.py`. **Some of these utilities will be helpful for completing your PoseCNN implementation.**

# %% [markdown]
# ## Putting it all together: PoseCNN
#
# We now have all the modules needed to make up our PoseCNN architecture. In the `PoseCNN` class of `pose_cnn.py`, add the translation and rotation branches to the initialization and forward functions. During training, your PoseCNN model should output a `loss_dict` variable with loss values for segmentation, translation and rotation branches stored respectively with keys of `"loss_segmentation"`, `"loss_centermap"`, and `"loss_R"`. The segmentation loss should be calculated using `rob599/p4_helpers.loss_cross_entropy`, the centroid loss should be calculated using l1Loss, and the rotation loss should be calculated using the provided helper in `rob599/p4_helpers.loss_Rotation`. During inference, your model should output a dictionary of predicted poses (i.e. see `PoseCNN.generate_pose` for a formatting utility) in `output_dict` and the predicted segmentation map (post processed probabilities) in `segmentation`.
#
# After this, you will be ready to train your PoseCNN model with all three losses:

# %%
import os
import time
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import rob599
from pose_cnn import PoseCNN
# torch.cuda.empty_cache()
# rob599.reset_seed(0)

# DEVICE = 'cpu'
dataloader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
posecnn_model = PoseCNN(pretrained_backbone = vgg16, 
                models_pcd = torch.tensor(train_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                cam_intrinsic = train_dataset.cam_intrinsic).to(DEVICE)
posecnn_model.train()
    
optimizer = torch.optim.Adam(posecnn_model.parameters(), lr=0.001,
                            betas=(0.9, 0.999))


loss_history = []
log_period = 5
_iter = 0


st_time = time.time()
for epoch in range(10):
    train_loss = []
    dataloader.dataset.dataset_type = 'train'
    for batch in dataloader:
        for item in batch:
            batch[item] = batch[item].to(DEVICE)
        loss_dict = posecnn_model(batch)
        optimizer.zero_grad()
        total_loss = 0
        for loss in loss_dict:
            total_loss += loss_dict[loss]
        total_loss.backward()
        optimizer.step()
        train_loss.append(total_loss.item())
        
        if _iter % log_period == 0:
            loss_str = f"[Iter {_iter}][loss: {total_loss:.3f}]"
            for key, value in loss_dict.items():
                loss_str += f"[{key}: {value:.3f}]"

            print(loss_str)
            loss_history.append(total_loss.item())
        _iter += 1
        
    print('Time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + \
                                  ', ' + 'Epoch %02d' % epoch + ', ' + 'Training finished' + f' , with mean training loss {np.array(train_loss).mean()}'))    

torch.save(posecnn_model.state_dict(), os.path.join(GOOGLE_DRIVE_PATH, "posecnn_model.pth"))
    
plt.title("Training loss history")
plt.xlabel(f"Iteration (x {log_period})")
plt.ylabel("Loss")
plt.plot(loss_history)
plt.show()
# Out:
# [Iter 0][loss: 3.636][loss_segmentation: 2.717][loss_centermap: 0.918][loss_R: 0.000]
# [Iter 5][loss: 2.267][loss_segmentation: 1.598][loss_centermap: 0.668][loss_R: 0.000]
# [Iter 10][loss: 1.636][loss_segmentation: 0.979][loss_centermap: 0.657][loss_R: 0.000]
# [Iter 15][loss: 1.355][loss_segmentation: 0.722][loss_centermap: 0.633][loss_R: 0.000]
# [Iter 20][loss: 1.236][loss_segmentation: 0.627][loss_centermap: 0.609][loss_R: 0.000]
# [Iter 25][loss: 1.080][loss_segmentation: 0.501][loss_centermap: 0.579][loss_R: 0.000]
# [Iter 30][loss: 1.059][loss_segmentation: 0.506][loss_centermap: 0.554][loss_R: 0.000]
# [Iter 35][loss: 0.993][loss_segmentation: 0.429][loss_centermap: 0.564][loss_R: 0.000]
# [Iter 40][loss: 0.928][loss_segmentation: 0.382][loss_centermap: 0.546][loss_R: 0.000]
# [Iter 45][loss: 0.874][loss_segmentation: 0.345][loss_centermap: 0.530][loss_R: 0.000]
# [Iter 50][loss: 0.931][loss_segmentation: 0.336][loss_centermap: 0.510][loss_R: 0.085]
# [Iter 55][loss: 0.929][loss_segmentation: 0.363][loss_centermap: 0.505][loss_R: 0.062]
# [Iter 60][loss: 0.868][loss_segmentation: 0.277][loss_centermap: 0.509][loss_R: 0.081]
# [Iter 65][loss: 0.790][loss_segmentation: 0.242][loss_centermap: 0.490][loss_R: 0.057]
# [Iter 70][loss: 0.804][loss_segmentation: 0.227][loss_centermap: 0.502][loss_R: 0.075]
# [Iter 75][loss: 0.776][loss_segmentation: 0.195][loss_centermap: 0.502][loss_R: 0.079]
# [Iter 80][loss: 0.740][loss_segmentation: 0.184][loss_centermap: 0.489][loss_R: 0.067]
# [Iter 85][loss: 0.745][loss_segmentation: 0.194][loss_centermap: 0.484][loss_R: 0.067]
# [Iter 90][loss: 0.704][loss_segmentation: 0.148][loss_centermap: 0.484][loss_R: 0.071]
# [Iter 95][loss: 0.731][loss_segmentation: 0.160][loss_centermap: 0.491][loss_R: 0.081]
# [Iter 100][loss: 0.705][loss_segmentation: 0.141][loss_centermap: 0.487][loss_R: 0.077]
# [Iter 105][loss: 0.752][loss_segmentation: 0.205][loss_centermap: 0.471][loss_R: 0.076]
# [Iter 110][loss: 0.687][loss_segmentation: 0.130][loss_centermap: 0.490][loss_R: 0.067]
# [Iter 115][loss: 0.675][loss_segmentation: 0.130][loss_centermap: 0.479][loss_R: 0.066]
# [Iter 120][loss: 0.672][loss_segmentation: 0.149][loss_centermap: 0.469][loss_R: 0.054]
# Time 00h 01m 43s, Epoch 00, Training finished , with mean training loss 0.9918008418083191
# [Iter 125][loss: 0.708][loss_segmentation: 0.181][loss_centermap: 0.463][loss_R: 0.064]
# [Iter 130][loss: 0.690][loss_segmentation: 0.143][loss_centermap: 0.471][loss_R: 0.077]
# [Iter 135][loss: 0.675][loss_segmentation: 0.139][loss_centermap: 0.472][loss_R: 0.064]
# [Iter 140][loss: 0.697][loss_segmentation: 0.162][loss_centermap: 0.475][loss_R: 0.061]
# [Iter 145][loss: 0.667][loss_segmentation: 0.144][loss_centermap: 0.460][loss_R: 0.064]
# [Iter 150][loss: 0.650][loss_segmentation: 0.136][loss_centermap: 0.460][loss_R: 0.054]
# [Iter 155][loss: 0.651][loss_segmentation: 0.138][loss_centermap: 0.456][loss_R: 0.057]
# [Iter 160][loss: 0.701][loss_segmentation: 0.156][loss_centermap: 0.474][loss_R: 0.072]
# [Iter 165][loss: 0.685][loss_segmentation: 0.157][loss_centermap: 0.462][loss_R: 0.065]
# [Iter 170][loss: 0.667][loss_segmentation: 0.144][loss_centermap: 0.461][loss_R: 0.062]
# [Iter 175][loss: 0.655][loss_segmentation: 0.138][loss_centermap: 0.462][loss_R: 0.054]
# [Iter 180][loss: 0.653][loss_segmentation: 0.136][loss_centermap: 0.458][loss_R: 0.059]
# [Iter 185][loss: 0.650][loss_segmentation: 0.125][loss_centermap: 0.467][loss_R: 0.058]
# [Iter 190][loss: 0.719][loss_segmentation: 0.192][loss_centermap: 0.468][loss_R: 0.059]
# [Iter 195][loss: 0.652][loss_segmentation: 0.133][loss_centermap: 0.463][loss_R: 0.056]
# [Iter 200][loss: 0.631][loss_segmentation: 0.112][loss_centermap: 0.457][loss_R: 0.062]
# [Iter 205][loss: 0.630][loss_segmentation: 0.123][loss_centermap: 0.453][loss_R: 0.053]
# [Iter 210][loss: 0.648][loss_segmentation: 0.131][loss_centermap: 0.458][loss_R: 0.058]
# [Iter 215][loss: 0.634][loss_segmentation: 0.118][loss_centermap: 0.458][loss_R: 0.058]
# [Iter 220][loss: 0.641][loss_segmentation: 0.114][loss_centermap: 0.464][loss_R: 0.064]
# [Iter 225][loss: 0.636][loss_segmentation: 0.109][loss_centermap: 0.466][loss_R: 0.061]
# [Iter 230][loss: 0.658][loss_segmentation: 0.136][loss_centermap: 0.450][loss_R: 0.072]
# [Iter 235][loss: 0.632][loss_segmentation: 0.110][loss_centermap: 0.461][loss_R: 0.061]
# [Iter 240][loss: 0.634][loss_segmentation: 0.119][loss_centermap: 0.456][loss_R: 0.060]
# [Iter 245][loss: 0.630][loss_segmentation: 0.133][loss_centermap: 0.448][loss_R: 0.049]
# Time 00h 03m 33s, Epoch 01, Training finished , with mean training loss 0.6552430906295776
# [Iter 250][loss: 0.628][loss_segmentation: 0.117][loss_centermap: 0.450][loss_R: 0.062]
# [Iter 255][loss: 0.637][loss_segmentation: 0.126][loss_centermap: 0.452][loss_R: 0.060]
# [Iter 260][loss: 0.631][loss_segmentation: 0.123][loss_centermap: 0.452][loss_R: 0.056]
# [Iter 265][loss: 0.657][loss_segmentation: 0.150][loss_centermap: 0.454][loss_R: 0.052]
# [Iter 270][loss: 0.611][loss_segmentation: 0.114][loss_centermap: 0.442][loss_R: 0.055]
# [Iter 275][loss: 0.615][loss_segmentation: 0.128][loss_centermap: 0.444][loss_R: 0.043]
# [Iter 280][loss: 0.617][loss_segmentation: 0.126][loss_centermap: 0.438][loss_R: 0.053]
# [Iter 285][loss: 0.641][loss_segmentation: 0.129][loss_centermap: 0.450][loss_R: 0.061]
# [Iter 290][loss: 0.633][loss_segmentation: 0.138][loss_centermap: 0.437][loss_R: 0.058]
# [Iter 295][loss: 0.625][loss_segmentation: 0.132][loss_centermap: 0.436][loss_R: 0.057]
# [Iter 300][loss: 0.615][loss_segmentation: 0.127][loss_centermap: 0.435][loss_R: 0.054]
# [Iter 305][loss: 0.617][loss_segmentation: 0.128][loss_centermap: 0.438][loss_R: 0.051]
# [Iter 310][loss: 0.603][loss_segmentation: 0.111][loss_centermap: 0.438][loss_R: 0.055]
# [Iter 315][loss: 0.615][loss_segmentation: 0.130][loss_centermap: 0.435][loss_R: 0.050]
# [Iter 320][loss: 0.625][loss_segmentation: 0.130][loss_centermap: 0.440][loss_R: 0.055]
# [Iter 325][loss: 0.637][loss_segmentation: 0.139][loss_centermap: 0.439][loss_R: 0.059]
# [Iter 330][loss: 0.623][loss_segmentation: 0.132][loss_centermap: 0.436][loss_R: 0.055]
# [Iter 335][loss: 0.614][loss_segmentation: 0.125][loss_centermap: 0.431][loss_R: 0.058]
# [Iter 340][loss: 0.611][loss_segmentation: 0.119][loss_centermap: 0.438][loss_R: 0.054]
# [Iter 345][loss: 0.604][loss_segmentation: 0.107][loss_centermap: 0.439][loss_R: 0.058]
# [Iter 350][loss: 0.597][loss_segmentation: 0.098][loss_centermap: 0.441][loss_R: 0.059]
# [Iter 355][loss: 0.603][loss_segmentation: 0.116][loss_centermap: 0.425][loss_R: 0.061]
# [Iter 360][loss: 0.595][loss_segmentation: 0.107][loss_centermap: 0.429][loss_R: 0.058]
# [Iter 365][loss: 0.596][loss_segmentation: 0.109][loss_centermap: 0.433][loss_R: 0.055]
# [Iter 370][loss: 0.613][loss_segmentation: 0.133][loss_centermap: 0.424][loss_R: 0.056]
# Time 00h 05m 24s, Epoch 02, Training finished , with mean training loss 0.6186429915428162
# [Iter 375][loss: 0.591][loss_segmentation: 0.111][loss_centermap: 0.422][loss_R: 0.058]
# [Iter 380][loss: 0.608][loss_segmentation: 0.127][loss_centermap: 0.424][loss_R: 0.058]
# [Iter 385][loss: 0.605][loss_segmentation: 0.125][loss_centermap: 0.422][loss_R: 0.058]
# [Iter 390][loss: 0.638][loss_segmentation: 0.154][loss_centermap: 0.423][loss_R: 0.061]
# [Iter 395][loss: 0.583][loss_segmentation: 0.114][loss_centermap: 0.416][loss_R: 0.053]
# [Iter 400][loss: 0.589][loss_segmentation: 0.126][loss_centermap: 0.419][loss_R: 0.044]
# [Iter 405][loss: 0.601][loss_segmentation: 0.128][loss_centermap: 0.420][loss_R: 0.054]
# [Iter 410][loss: 0.607][loss_segmentation: 0.126][loss_centermap: 0.419][loss_R: 0.062]
# [Iter 415][loss: 0.631][loss_segmentation: 0.150][loss_centermap: 0.419][loss_R: 0.062]
# [Iter 420][loss: 0.598][loss_segmentation: 0.131][loss_centermap: 0.409][loss_R: 0.058]
# [Iter 425][loss: 0.592][loss_segmentation: 0.126][loss_centermap: 0.413][loss_R: 0.054]
# [Iter 430][loss: 0.598][loss_segmentation: 0.125][loss_centermap: 0.418][loss_R: 0.055]
# [Iter 435][loss: 0.579][loss_segmentation: 0.111][loss_centermap: 0.412][loss_R: 0.055]
# [Iter 440][loss: 0.596][loss_segmentation: 0.129][loss_centermap: 0.418][loss_R: 0.050]
# [Iter 445][loss: 0.603][loss_segmentation: 0.129][loss_centermap: 0.419][loss_R: 0.055]
# [Iter 450][loss: 0.584][loss_segmentation: 0.105][loss_centermap: 0.416][loss_R: 0.063]
# [Iter 455][loss: 0.585][loss_segmentation: 0.116][loss_centermap: 0.414][loss_R: 0.055]
# [Iter 460][loss: 0.585][loss_segmentation: 0.120][loss_centermap: 0.405][loss_R: 0.060]
# [Iter 465][loss: 0.575][loss_segmentation: 0.107][loss_centermap: 0.406][loss_R: 0.063]
# [Iter 470][loss: 0.578][loss_segmentation: 0.105][loss_centermap: 0.408][loss_R: 0.065]
# [Iter 475][loss: 0.571][loss_segmentation: 0.093][loss_centermap: 0.411][loss_R: 0.067]
# [Iter 480][loss: 0.606][loss_segmentation: 0.126][loss_centermap: 0.412][loss_R: 0.068]
# [Iter 485][loss: 0.579][loss_segmentation: 0.106][loss_centermap: 0.407][loss_R: 0.066]
# [Iter 490][loss: 0.579][loss_segmentation: 0.109][loss_centermap: 0.407][loss_R: 0.063]
# [Iter 495][loss: 0.585][loss_segmentation: 0.130][loss_centermap: 0.399][loss_R: 0.056]
# Time 00h 07m 14s, Epoch 03, Training finished , with mean training loss 0.5934063892364502
# [Iter 500][loss: 0.589][loss_segmentation: 0.121][loss_centermap: 0.407][loss_R: 0.061]
# [Iter 505][loss: 0.594][loss_segmentation: 0.126][loss_centermap: 0.409][loss_R: 0.059]
# [Iter 510][loss: 0.581][loss_segmentation: 0.120][loss_centermap: 0.398][loss_R: 0.063]
# [Iter 515][loss: 0.603][loss_segmentation: 0.144][loss_centermap: 0.399][loss_R: 0.060]
# [Iter 520][loss: 0.566][loss_segmentation: 0.112][loss_centermap: 0.392][loss_R: 0.062]
# [Iter 525][loss: 0.590][loss_segmentation: 0.136][loss_centermap: 0.404][loss_R: 0.050]
# [Iter 530][loss: 0.585][loss_segmentation: 0.123][loss_centermap: 0.403][loss_R: 0.059]
# [Iter 535][loss: 0.593][loss_segmentation: 0.134][loss_centermap: 0.393][loss_R: 0.066]
# [Iter 540][loss: 0.588][loss_segmentation: 0.140][loss_centermap: 0.388][loss_R: 0.060]
# [Iter 545][loss: 0.570][loss_segmentation: 0.129][loss_centermap: 0.385][loss_R: 0.057]
# [Iter 550][loss: 0.571][loss_segmentation: 0.128][loss_centermap: 0.387][loss_R: 0.055]
# [Iter 555][loss: 0.583][loss_segmentation: 0.125][loss_centermap: 0.397][loss_R: 0.061]
# [Iter 560][loss: 0.560][loss_segmentation: 0.111][loss_centermap: 0.387][loss_R: 0.061]
# [Iter 565][loss: 0.570][loss_segmentation: 0.134][loss_centermap: 0.392][loss_R: 0.043]
# [Iter 570][loss: 0.558][loss_segmentation: 0.120][loss_centermap: 0.385][loss_R: 0.053]
# [Iter 575][loss: 0.545][loss_segmentation: 0.100][loss_centermap: 0.385][loss_R: 0.060]
# [Iter 580][loss: 0.544][loss_segmentation: 0.115][loss_centermap: 0.378][loss_R: 0.051]
# [Iter 585][loss: 0.553][loss_segmentation: 0.121][loss_centermap: 0.376][loss_R: 0.056]
# [Iter 590][loss: 0.537][loss_segmentation: 0.106][loss_centermap: 0.375][loss_R: 0.055]
# [Iter 595][loss: 0.542][loss_segmentation: 0.103][loss_centermap: 0.377][loss_R: 0.061]
# [Iter 600][loss: 0.527][loss_segmentation: 0.092][loss_centermap: 0.374][loss_R: 0.062]
# [Iter 605][loss: 0.543][loss_segmentation: 0.114][loss_centermap: 0.366][loss_R: 0.064]
# [Iter 610][loss: 0.531][loss_segmentation: 0.104][loss_centermap: 0.367][loss_R: 0.060]
# [Iter 615][loss: 0.542][loss_segmentation: 0.109][loss_centermap: 0.376][loss_R: 0.058]
# [Iter 620][loss: 0.530][loss_segmentation: 0.127][loss_centermap: 0.356][loss_R: 0.047]
# Time 00h 09m 05s, Epoch 04, Training finished , with mean training loss 0.5620724444389343
# [Iter 625][loss: 0.537][loss_segmentation: 0.110][loss_centermap: 0.369][loss_R: 0.058]
# [Iter 630][loss: 0.538][loss_segmentation: 0.119][loss_centermap: 0.359][loss_R: 0.060]
# [Iter 635][loss: 0.527][loss_segmentation: 0.118][loss_centermap: 0.352][loss_R: 0.057]
# [Iter 640][loss: 0.544][loss_segmentation: 0.137][loss_centermap: 0.352][loss_R: 0.056]
# [Iter 645][loss: 0.524][loss_segmentation: 0.112][loss_centermap: 0.359][loss_R: 0.052]
# [Iter 650][loss: 0.529][loss_segmentation: 0.122][loss_centermap: 0.363][loss_R: 0.044]
# [Iter 655][loss: 0.537][loss_segmentation: 0.122][loss_centermap: 0.362][loss_R: 0.053]
# [Iter 660][loss: 0.531][loss_segmentation: 0.120][loss_centermap: 0.351][loss_R: 0.059]
# [Iter 665][loss: 0.555][loss_segmentation: 0.144][loss_centermap: 0.354][loss_R: 0.057]
# [Iter 670][loss: 0.533][loss_segmentation: 0.129][loss_centermap: 0.353][loss_R: 0.051]
# [Iter 675][loss: 0.530][loss_segmentation: 0.124][loss_centermap: 0.359][loss_R: 0.047]
# [Iter 680][loss: 0.545][loss_segmentation: 0.126][loss_centermap: 0.362][loss_R: 0.057]
# [Iter 685][loss: 0.514][loss_segmentation: 0.106][loss_centermap: 0.355][loss_R: 0.053]
# [Iter 690][loss: 0.521][loss_segmentation: 0.126][loss_centermap: 0.351][loss_R: 0.044]
# [Iter 695][loss: 0.527][loss_segmentation: 0.118][loss_centermap: 0.355][loss_R: 0.053]
# [Iter 700][loss: 0.519][loss_segmentation: 0.099][loss_centermap: 0.362][loss_R: 0.059]
# [Iter 705][loss: 0.523][loss_segmentation: 0.114][loss_centermap: 0.360][loss_R: 0.050]
# [Iter 710][loss: 0.514][loss_segmentation: 0.118][loss_centermap: 0.342][loss_R: 0.055]
# [Iter 715][loss: 0.510][loss_segmentation: 0.105][loss_centermap: 0.351][loss_R: 0.054]
# [Iter 720][loss: 0.528][loss_segmentation: 0.108][loss_centermap: 0.362][loss_R: 0.058]
# [Iter 725][loss: 0.507][loss_segmentation: 0.091][loss_centermap: 0.355][loss_R: 0.060]
# [Iter 730][loss: 0.533][loss_segmentation: 0.113][loss_centermap: 0.354][loss_R: 0.066]
# [Iter 735][loss: 0.511][loss_segmentation: 0.102][loss_centermap: 0.349][loss_R: 0.060]
# [Iter 740][loss: 0.528][loss_segmentation: 0.107][loss_centermap: 0.363][loss_R: 0.058]
# [Iter 745][loss: 0.513][loss_segmentation: 0.126][loss_centermap: 0.340][loss_R: 0.047]
# Time 00h 10m 55s, Epoch 05, Training finished , with mean training loss 0.5272372431755066
# [Iter 750][loss: 0.527][loss_segmentation: 0.108][loss_centermap: 0.359][loss_R: 0.060]
# [Iter 755][loss: 0.523][loss_segmentation: 0.118][loss_centermap: 0.344][loss_R: 0.061]
# [Iter 760][loss: 0.510][loss_segmentation: 0.116][loss_centermap: 0.337][loss_R: 0.057]
# [Iter 765][loss: 0.530][loss_segmentation: 0.146][loss_centermap: 0.336][loss_R: 0.048]
# [Iter 770][loss: 0.508][loss_segmentation: 0.111][loss_centermap: 0.345][loss_R: 0.052]
# [Iter 775][loss: 0.514][loss_segmentation: 0.121][loss_centermap: 0.348][loss_R: 0.045]
# [Iter 780][loss: 0.520][loss_segmentation: 0.122][loss_centermap: 0.345][loss_R: 0.053]
# [Iter 785][loss: 0.504][loss_segmentation: 0.120][loss_centermap: 0.325][loss_R: 0.059]
# [Iter 790][loss: 0.508][loss_segmentation: 0.129][loss_centermap: 0.324][loss_R: 0.055]
# [Iter 795][loss: 0.511][loss_segmentation: 0.127][loss_centermap: 0.332][loss_R: 0.053]
# [Iter 800][loss: 0.511][loss_segmentation: 0.126][loss_centermap: 0.339][loss_R: 0.045]
# [Iter 805][loss: 0.523][loss_segmentation: 0.123][loss_centermap: 0.348][loss_R: 0.053]
# [Iter 810][loss: 0.497][loss_segmentation: 0.105][loss_centermap: 0.339][loss_R: 0.053]
# [Iter 815][loss: 0.510][loss_segmentation: 0.126][loss_centermap: 0.341][loss_R: 0.043]
# [Iter 820][loss: 0.510][loss_segmentation: 0.118][loss_centermap: 0.339][loss_R: 0.053]
# [Iter 825][loss: 0.502][loss_segmentation: 0.097][loss_centermap: 0.348][loss_R: 0.057]
# [Iter 830][loss: 0.503][loss_segmentation: 0.114][loss_centermap: 0.338][loss_R: 0.052]
# [Iter 835][loss: 0.502][loss_segmentation: 0.119][loss_centermap: 0.330][loss_R: 0.053]
# [Iter 840][loss: 0.499][loss_segmentation: 0.105][loss_centermap: 0.341][loss_R: 0.053]
# [Iter 845][loss: 0.492][loss_segmentation: 0.100][loss_centermap: 0.333][loss_R: 0.059]
# [Iter 850][loss: 0.482][loss_segmentation: 0.089][loss_centermap: 0.334][loss_R: 0.059]
# [Iter 855][loss: 0.511][loss_segmentation: 0.112][loss_centermap: 0.337][loss_R: 0.062]
# [Iter 860][loss: 0.487][loss_segmentation: 0.100][loss_centermap: 0.328][loss_R: 0.059]
# [Iter 865][loss: 0.503][loss_segmentation: 0.104][loss_centermap: 0.343][loss_R: 0.057]
# [Iter 870][loss: 0.504][loss_segmentation: 0.127][loss_centermap: 0.331][loss_R: 0.046]
# Time 00h 12m 45s, Epoch 06, Training finished , with mean training loss 0.5090342392921448
# [Iter 875][loss: 0.533][loss_segmentation: 0.120][loss_centermap: 0.355][loss_R: 0.059]
# [Iter 880][loss: 0.552][loss_segmentation: 0.125][loss_centermap: 0.369][loss_R: 0.058]
# [Iter 885][loss: 0.507][loss_segmentation: 0.117][loss_centermap: 0.333][loss_R: 0.058]
# [Iter 890][loss: 0.521][loss_segmentation: 0.137][loss_centermap: 0.328][loss_R: 0.056]
# [Iter 895][loss: 0.503][loss_segmentation: 0.110][loss_centermap: 0.338][loss_R: 0.055]
# [Iter 900][loss: 0.499][loss_segmentation: 0.121][loss_centermap: 0.336][loss_R: 0.042]
# [Iter 905][loss: 0.505][loss_segmentation: 0.121][loss_centermap: 0.331][loss_R: 0.053]
# [Iter 910][loss: 0.492][loss_segmentation: 0.117][loss_centermap: 0.313][loss_R: 0.062]
# [Iter 915][loss: 0.502][loss_segmentation: 0.128][loss_centermap: 0.317][loss_R: 0.057]
# [Iter 920][loss: 0.496][loss_segmentation: 0.126][loss_centermap: 0.317][loss_R: 0.053]
# [Iter 925][loss: 0.493][loss_segmentation: 0.122][loss_centermap: 0.325][loss_R: 0.046]
# [Iter 930][loss: 0.512][loss_segmentation: 0.121][loss_centermap: 0.338][loss_R: 0.053]
# [Iter 935][loss: 0.498][loss_segmentation: 0.109][loss_centermap: 0.335][loss_R: 0.054]
# [Iter 940][loss: 0.505][loss_segmentation: 0.125][loss_centermap: 0.333][loss_R: 0.046]
# [Iter 945][loss: 0.502][loss_segmentation: 0.118][loss_centermap: 0.331][loss_R: 0.054]
# [Iter 950][loss: 0.498][loss_segmentation: 0.099][loss_centermap: 0.340][loss_R: 0.059]
# [Iter 955][loss: 0.495][loss_segmentation: 0.114][loss_centermap: 0.331][loss_R: 0.050]
# [Iter 960][loss: 0.512][loss_segmentation: 0.124][loss_centermap: 0.329][loss_R: 0.059]
# [Iter 965][loss: 0.481][loss_segmentation: 0.103][loss_centermap: 0.326][loss_R: 0.052]
# [Iter 970][loss: 0.485][loss_segmentation: 0.100][loss_centermap: 0.325][loss_R: 0.059]
# [Iter 975][loss: 0.475][loss_segmentation: 0.089][loss_centermap: 0.325][loss_R: 0.060]
# [Iter 980][loss: 0.497][loss_segmentation: 0.114][loss_centermap: 0.322][loss_R: 0.061]
# [Iter 985][loss: 0.477][loss_segmentation: 0.102][loss_centermap: 0.317][loss_R: 0.058]
# [Iter 990][loss: 0.490][loss_segmentation: 0.104][loss_centermap: 0.332][loss_R: 0.054]
# [Iter 995][loss: 0.498][loss_segmentation: 0.125][loss_centermap: 0.322][loss_R: 0.051]
# Time 00h 14m 35s, Epoch 07, Training finished , with mean training loss 0.5005925076007843
# [Iter 1000][loss: 0.502][loss_segmentation: 0.108][loss_centermap: 0.341][loss_R: 0.054]
# [Iter 1005][loss: 0.504][loss_segmentation: 0.119][loss_centermap: 0.326][loss_R: 0.059]
# [Iter 1010][loss: 0.493][loss_segmentation: 0.117][loss_centermap: 0.317][loss_R: 0.058]
# [Iter 1015][loss: 0.494][loss_segmentation: 0.133][loss_centermap: 0.302][loss_R: 0.058]
# [Iter 1020][loss: 0.483][loss_segmentation: 0.108][loss_centermap: 0.325][loss_R: 0.049]
# [Iter 1025][loss: 0.501][loss_segmentation: 0.121][loss_centermap: 0.333][loss_R: 0.047]
# [Iter 1030][loss: 0.495][loss_segmentation: 0.119][loss_centermap: 0.322][loss_R: 0.054]
# [Iter 1035][loss: 0.477][loss_segmentation: 0.118][loss_centermap: 0.300][loss_R: 0.059]
# [Iter 1040][loss: 0.487][loss_segmentation: 0.127][loss_centermap: 0.300][loss_R: 0.059]
# [Iter 1045][loss: 0.483][loss_segmentation: 0.125][loss_centermap: 0.303][loss_R: 0.056]
# [Iter 1050][loss: 0.489][loss_segmentation: 0.121][loss_centermap: 0.319][loss_R: 0.049]
# [Iter 1055][loss: 0.502][loss_segmentation: 0.122][loss_centermap: 0.326][loss_R: 0.055]
# [Iter 1060][loss: 0.476][loss_segmentation: 0.103][loss_centermap: 0.320][loss_R: 0.053]
# [Iter 1065][loss: 0.497][loss_segmentation: 0.124][loss_centermap: 0.322][loss_R: 0.051]
# [Iter 1070][loss: 0.489][loss_segmentation: 0.116][loss_centermap: 0.319][loss_R: 0.053]
# [Iter 1075][loss: 0.479][loss_segmentation: 0.096][loss_centermap: 0.327][loss_R: 0.056]
# [Iter 1080][loss: 0.487][loss_segmentation: 0.112][loss_centermap: 0.324][loss_R: 0.050]
# [Iter 1085][loss: 0.483][loss_segmentation: 0.116][loss_centermap: 0.313][loss_R: 0.054]
# [Iter 1090][loss: 0.472][loss_segmentation: 0.103][loss_centermap: 0.319][loss_R: 0.050]
# [Iter 1095][loss: 0.470][loss_segmentation: 0.099][loss_centermap: 0.313][loss_R: 0.058]
# [Iter 1100][loss: 0.459][loss_segmentation: 0.088][loss_centermap: 0.314][loss_R: 0.057]
# [Iter 1105][loss: 0.486][loss_segmentation: 0.111][loss_centermap: 0.317][loss_R: 0.057]
# [Iter 1110][loss: 0.464][loss_segmentation: 0.099][loss_centermap: 0.307][loss_R: 0.058]
# [Iter 1115][loss: 0.488][loss_segmentation: 0.103][loss_centermap: 0.330][loss_R: 0.055]
# [Iter 1120][loss: 0.491][loss_segmentation: 0.124][loss_centermap: 0.315][loss_R: 0.052]
# Time 00h 16m 24s, Epoch 08, Training finished , with mean training loss 0.4882602114677429
# [Iter 1125][loss: 0.484][loss_segmentation: 0.106][loss_centermap: 0.326][loss_R: 0.053]
# [Iter 1130][loss: 0.485][loss_segmentation: 0.117][loss_centermap: 0.312][loss_R: 0.056]
# [Iter 1135][loss: 0.476][loss_segmentation: 0.114][loss_centermap: 0.307][loss_R: 0.055]
# [Iter 1140][loss: 0.502][loss_segmentation: 0.137][loss_centermap: 0.305][loss_R: 0.060]
# [Iter 1145][loss: 0.487][loss_segmentation: 0.112][loss_centermap: 0.327][loss_R: 0.048]
# [Iter 1150][loss: 0.494][loss_segmentation: 0.121][loss_centermap: 0.328][loss_R: 0.045]
# [Iter 1155][loss: 0.492][loss_segmentation: 0.120][loss_centermap: 0.319][loss_R: 0.053]
# [Iter 1160][loss: 0.485][loss_segmentation: 0.120][loss_centermap: 0.303][loss_R: 0.062]
# [Iter 1165][loss: 0.492][loss_segmentation: 0.129][loss_centermap: 0.303][loss_R: 0.060]
# [Iter 1170][loss: 0.484][loss_segmentation: 0.124][loss_centermap: 0.304][loss_R: 0.056]
# [Iter 1175][loss: 0.484][loss_segmentation: 0.122][loss_centermap: 0.315][loss_R: 0.048]
# [Iter 1180][loss: 0.488][loss_segmentation: 0.120][loss_centermap: 0.317][loss_R: 0.052]
# [Iter 1185][loss: 0.470][loss_segmentation: 0.104][loss_centermap: 0.313][loss_R: 0.053]
# [Iter 1190][loss: 0.497][loss_segmentation: 0.127][loss_centermap: 0.320][loss_R: 0.049]
# [Iter 1195][loss: 0.476][loss_segmentation: 0.116][loss_centermap: 0.309][loss_R: 0.051]
# [Iter 1200][loss: 0.467][loss_segmentation: 0.097][loss_centermap: 0.317][loss_R: 0.053]
# [Iter 1205][loss: 0.477][loss_segmentation: 0.112][loss_centermap: 0.314][loss_R: 0.050]
# [Iter 1210][loss: 0.479][loss_segmentation: 0.119][loss_centermap: 0.306][loss_R: 0.053]
# [Iter 1215][loss: 0.467][loss_segmentation: 0.103][loss_centermap: 0.313][loss_R: 0.051]
# [Iter 1220][loss: 0.472][loss_segmentation: 0.099][loss_centermap: 0.313][loss_R: 0.060]
# [Iter 1225][loss: 0.459][loss_segmentation: 0.090][loss_centermap: 0.312][loss_R: 0.057]
# [Iter 1230][loss: 0.490][loss_segmentation: 0.110][loss_centermap: 0.315][loss_R: 0.065]
# [Iter 1235][loss: 0.461][loss_segmentation: 0.100][loss_centermap: 0.301][loss_R: 0.060]
# [Iter 1240][loss: 0.479][loss_segmentation: 0.102][loss_centermap: 0.320][loss_R: 0.056]
# [Iter 1245][loss: 0.479][loss_segmentation: 0.124][loss_centermap: 0.307][loss_R: 0.048]
# Time 00h 18m 15s, Epoch 09, Training finished , with mean training loss 0.48138095951080323

# %% [markdown]
# ### Inference
#
# Visualize a few outputs from the full trained model. These could be improved if we used a larger model, trained for greater duration, and if we used ICP with depth data to refine the final estimates.

# %%
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import rob599
from pose_cnn import PoseCNN, eval

DEVICE = 'cpu'
rob599.reset_seed(0)

dataloader = DataLoader(dataset=val_dataset, batch_size=BATCH_SIZE)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
posecnn_model = PoseCNN(pretrained_backbone = vgg16, 
                models_pcd = torch.tensor(val_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                cam_intrinsic = val_dataset.cam_intrinsic).to(DEVICE)
posecnn_model.load_state_dict(torch.load(os.path.join(GOOGLE_DRIVE_PATH, "posecnn_model.pth")))

num_samples = 5
for i in range(num_samples):
    out = eval(posecnn_model, dataloader, DEVICE)

    plt.axis('off')
    plt.imshow(out)
    plt.show()
# Out:
# /tmp/ipykernel_11996/4123885673.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   posecnn_model.load_state_dict(torch.load(os.path.join(GOOGLE_DRIVE_PATH, "posecnn_model.pth")))
# tensor(10)
# tensor([[[[0.5832, 0.5832, 0.5832,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5832, 0.5832, 0.5832,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5832, 0.5832, 0.5832,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.4785, 0.4785, 0.4785,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4785, 0.4785, 0.4785,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4785, 0.4785, 0.4785,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.7641, 0.7641, 0.7641,  ..., 0.6520, 0.6520, 0.6520],
#           [0.7641, 0.7641, 0.7641,  ..., 0.6520, 0.6520, 0.6520],
#           [0.7641, 0.7641, 0.7641,  ..., 0.6520, 0.6520, 0.6520],
#           ...,
#           [0.9746, 0.9746, 0.9746,  ..., 0.8135, 0.8135, 0.8135],
#           [0.9746, 0.9746, 0.9746,  ..., 0.8135, 0.8135, 0.8135],
#           [0.9746, 0.9746, 0.9746,  ..., 0.8135, 0.8135, 0.8135]],
#
#          ...,
#
#          [[0.8572, 0.8572, 0.8572,  ..., 0.0000, 0.0000, 0.0000],
#           [0.8572, 0.8572, 0.8572,  ..., 0.0000, 0.0000, 0.0000],
#           [0.8572, 0.8572, 0.8572,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [1.0449, 1.0449, 1.0449,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0449, 1.0449, 1.0449,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0449, 1.0449, 1.0449,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.6329, 0.6329, 0.6329,  ..., 0.3219, 0.3219, 0.3219],
#           [0.6329, 0.6329, 0.6329,  ..., 0.3219, 0.3219, 0.3219],
#           [0.6329, 0.6329, 0.6329,  ..., 0.3219, 0.3219, 0.3219],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[1.0249, 1.0249, 1.0249,  ..., 1.1083, 1.1083, 1.1083],
#           [1.0249, 1.0249, 1.0249,  ..., 1.1083, 1.1083, 1.1083],
#           [1.0249, 1.0249, 1.0249,  ..., 1.1083, 1.1083, 1.1083],
#           ...,
#           [0.8491, 0.8491, 0.8491,  ..., 0.9995, 0.9995, 0.9995],
#           [0.8491, 0.8491, 0.8491,  ..., 0.9995, 0.9995, 0.9995],
#           [0.8491, 0.8491, 0.8491,  ..., 0.9995, 0.9995, 0.9995]]]])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 21
#      19 num_samples = 5
#      20 for i in range(num_samples):
# ---> 21     out = eval(posecnn_model, dataloader, DEVICE)
#      23     plt.axis('off')
#      24     plt.imshow(out)
#
# File ~/Documents/higger/deeprobp4/P4/pose_cnn.py:507, in eval(model, dataloader, device, alpha)
#     505 rgb = torch.tensor(dataloader.dataset[sample_idx]['rgb'][None, :]).to(device)
#     506 inputdict = {'rgb': rgb}
# --> 507 pose_dict, label = model(inputdict)
#     508 poselist = []
#     509 rgb =  (rgb[0].cpu().numpy().transpose(1, 2, 0) * 255).astype(np.uint8)
#
# File ~/anaconda3/envs/deeprob_new/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/deeprob_new/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/higger/deeprobp4/P4/pose_cnn.py:397, in PoseCNN.forward(self, input_dict)
#     395 print(torch.max(segmentation))
#     396 print(translation)
# --> 397 pred_centers, pred_depth = HoughVoting(segmentation, translation)
#     398 output_dict = self.generate_pose(predRot, pred_centers, pred_depth, bbx)
#     400 ######################################################################
#     401 #                            END OF YOUR CODE                        #
#     402 ######################################################################
#
# File ~/Documents/higger/deeprobp4/P4/rob599/p4_helpers.py:125, in HoughVoting(label, centermap, num_classes)
#     123 mask = (y_index >= 0) * (y_index < H)
#     124 count = y_index * W + x_index.unsqueeze(dim=0)
# --> 125 center, inlier_num = torch.bincount(count[mask]).argmax(), torch.bincount(count[mask]).max()
#     126 center_x, center_y = center % W, torch.div(center, W, rounding_mode='trunc')
#     127 if inlier_num > _HOUGHVOTING_NUM_INLIER:
#
# IndexError: argmax(): Expected reduction dim to be specified for input.numel() == 0.

# %% [markdown]
# Finally, let's measure the quantitative accuracy of our trained model using the 5°5cm metric. That is, we'll count how many visible objects our model was able to predict correctly, where a correct prediction is defined as one with a rotation error of less than 5° and a translation error of less than 5cm.
#
# The instructor's model, trained with the hyperparameters above achieves 35.04%.

# %%
import math
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import pyquaternion
from tqdm import tqdm

import rob599
from pose_cnn import PoseCNN

rob599.reset_seed(0)

dataloader = DataLoader(dataset=val_dataset, batch_size=BATCH_SIZE)

posecnn_model.load_state_dict(torch.load(os.path.join(GOOGLE_DRIVE_PATH, "posecnn_model.pth")))
posecnn_model.eval()


T_thresh = 5 # cm
R_thresh = 5 # deg

total =0
correct = 0
for batch in tqdm(dataloader):
    for item in batch:
        batch[item] = batch[item].to(DEVICE)
    pose_dict, segmentation = posecnn_model(batch)
    for bidx in range(BATCH_SIZE):
        objs_visib = batch['objs_id'][bidx].cpu().tolist()
        objs_preds = sorted(list(pose_dict[bidx].keys()))
        for objidx, objs_id in enumerate(objs_visib):
            if objs_id==0:
                continue

            total += 1
            if objs_id not in objs_preds:
                continue
            RT_pred = pose_dict[bidx][objs_id]
            RT_true = batch['RTs'][bidx][objidx].cpu().numpy()

            # Translation error
            T_pred = RT_pred[:3,3]
            T_true = RT_true[:3,3]
            T_err = 100*np.linalg.norm(T_pred-T_true) # error in cm

            # Rotation error
            R_true = pyquaternion.Quaternion(matrix=RT_true[:3,:3],atol=1e-6)
            R_pred = pyquaternion.Quaternion(matrix=RT_pred[:3,:3],atol=1e-6)

            R_rel = R_pred * R_true.conjugate
            R_err = math.degrees(R_rel.angle)

            if T_err<T_thresh and R_err<R_thresh:
                correct+=1

print("Accuracy at 5°5cm:",correct/total)

# %% [markdown]
# ## Verifying notebook cells
#
# Before moving onto the next part of the project, we can verify that no
# unexpected cells have been added or removed by **saving this file** then using the following cell:

# %%
from rob599.p4_helpers import verify_notebook_cells

notebook_path = os.path.join(GOOGLE_DRIVE_PATH, 'pose_estimation.ipynb')
verify_notebook_cells(notebook_path, expected_count=54)

# %% [markdown]
# We now can move on to the next part of the project in the `vision_transformers.ipynb` file.
